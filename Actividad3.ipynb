# %% [markdown]
# <a href="https://colab.research.google.com/github/Jose-Angel009/Unidad-3/blob/main/Actividad3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Actividad 3
# Matplotlib es una libreria de frajados de graficos de bajo nivel en python que sirve como una herramienta de visualizacion.
# Matplotlib esta escrito principalmente en python con algunas semegansas escrito en c.Instalacion de Matplotlib.Tienes python y pip ya instalado en tu en tu sistema,instala Matplotlib  usando el siguiente comando:pip install Matplotlib desde la linea de comandos import Matplotlib una vez instalado V importalo en tus aplicaciones agregando el modulo import ejemplo:import Matplotlib
# Matplotlib pyplot
# pyplot
# la mayoria  de las herramientas de Matplotlib se encuentra dentro de  submodulos pyplot y normalmente se importan bajo el alias plt
# import Matplotlib.pplot as plt
# Ahora el paquete pyplot puededenominar plt.
